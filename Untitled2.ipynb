# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

import matplotlib.style as style
style.use('seaborn-whitegrid')

import os
import re
# import googlemaps
# import time
import pickle
from collections import defaultdict

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import RidgeCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import mean_squared_error

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, TreebankWordTokenizer, wordpunct_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
from nltk.util import ngrams
from nltk.corpus import stopwords

from textblob import TextBlob

import string

# %%
import matplotlib.style as style
plt.style.use('seaborn-whitegrid')

# %%
# Set pandas options
pd.set_option('max_rows', 10)
# pd.set_option('max_colwidth', -1)
# pd.set_option('display.width', 150)
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)

# %% [markdown]
# *Load the relevant data file*

# %%
# df = pd.read_csv('data/cleaned_reviews.csv')
# df = pd.read_csv('data/listing_descriptions.csv', index_col=0)
# df = pd.read_csv('data/cleaned_df.csv', index_col='Unnamed: 0')
# df2 = pd.read_csv('data/df_with_lda.csv', index_col='Unnamed: 0')
df3 = pd.read_csv('final_full_df.csv', index_col='Unnamed: 0')
# Out:
# /Users/brenner/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sns.set_context('talk')

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.hist(df3['polarity'], bins=25, edgecolor='black', cumulative=False);
ax.set_xlim(0.0, 1.0)
ax.set_xlabel('Polarity', labelpad=30, fontsize=30)

ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)

ax.set_yticklabels(['', '10,000', '20,000', '30,000', '40,000', '50,000', '60,000'])

ax.set_ylabel('Count', labelpad=30, fontsize=30)
ax.set_xticklabels([0, .2, .4, .6, .8, 1])
plt.tight_layout()

# plt.savefig('plots/walk_score_and_home_price.jpg')

# %%
df3.head(1)
# Out:
#    id_x  host_id  host_listings_count  host_total_listings_count  \
# 0  7893    21489                    1                          1
#
#   neighbourhood zipcode   latitude   longitude property_type        room_type  \
# 0      Piedmont   97217  45.575479 -122.666777         House  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             3        1.0       2.0   2.0  Real Bed
#
#                                            amenities  price  guests_included  \
# 0  {TV,Wifi,Kitchen,"Free parking on premises","I...    175                1
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                  2                 100.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
#
#    instant_bookable  reviews_per_month  listing_id   id_y        date  \
# 0                 0               0.02        7893  27282  2010-02-22
#
#    reviewer_id reviewer_name  \
# 0        52074         Shaun
#
#                                             comments  \
# 0  Couldn't possibly had a better experience with...
#
#                                  reviews_cleaned_str  polarity  subjectivity  \
# 0  couldnt possibl better experi trip would give ...     0.275          0.65
#
#    review_length                                   cleaned_comments  \
# 0            158  couldnt possibly better experience trip would ...
#
#    num_sentences                                 comment_words_only  \
# 0              3  couldnt possibly had a better experience with ...
#
#                                     individual_words  word_count  \
# 0  ['couldnt', 'possibly', 'had', 'a', 'better', ...          29
#
#    average_word_length most_frequent_words  cluster_pred     lda_1     lda_2  \
# 0             4.241379                  []             3  0.272123  0.594522
#
#       lda_3     lda_4     lda_5    lda_6     lda_7     lda_8     lda_9  \
# 0  0.016668  0.016668  0.016672  0.01667  0.016672  0.016669  0.016668
#
#      lda_10
# 0  0.016669

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.hist(df3['review_scores_rating'], range=(85,100), bins=15, color = 'orange', edgecolor='black')
# sns.countplot(df3['review_scores_rating'], ax=ax, color='green', edgecolor='black')
# ax.set_title('Ratings by Review')
ax.set_xlim(85, 100.1)
ax.set_xlabel('Rating', labelpad=30, fontsize=30)
ax.set_xticks(ticks=[85, 90, 95, 100])
# ax.set_xticklabels([0, 20, 40, 60, 80, 100])
# ax.set_xticklabels([0, .2, .4, .6, .8, 1])

ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)

# ax.set_yticklabels(['', '10,000', '20,000', '30,000', '40,000', '50,000', '60,000'])

ax.set_ylabel('Count', labelpad=30, fontsize=30)

plt.tight_layout()

# plt.savefig('plots/walk_score_and_home_price.jpg')
# Out:
# /Users/brenner/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:720: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/brenner/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:721: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
prices = df3['price'].astype(int)

# %%
x = df3[df3['price'] <= 500]

# %%
# Out:
# 0         175
# 1         175
# 2          65
# 3          65
# 4          65
# 5          65
# 6          65
# 7          65
# 8          65
# 9          65
# 10         65
# 11         65
# 12         65
# 13         65
# 14         65
#          ...
# 318247     75
# 318248     50
# 318249     65
# 318250     65
# 318251     70
# 318252     85
# 318253     99
# 318254     85
# 318255     85
# 318256    199
# 318257     79
# 318258     79
# 318259     69
# 318260    150
# 318261     73
# Name: price, Length: 317748, dtype: int64

# %%
plt.hist(df3['price'], bins=50)
# Out:
# (array([2.94279e+05, 2.11220e+04, 2.34700e+03, 2.44000e+02, 2.60000e+01,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 6.50000e+01, 0.00000e+00,
#         0.00000e+00, 2.30000e+01, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.56000e+02]),
#  array([   0.,  168.,  336.,  504.,  672.,  840., 1008., 1176., 1344.,
#         1512., 1680., 1848., 2016., 2184., 2352., 2520., 2688., 2856.,
#         3024., 3192., 3360., 3528., 3696., 3864., 4032., 4200., 4368.,
#         4536., 4704., 4872., 5040., 5208., 5376., 5544., 5712., 5880.,
#         6048., 6216., 6384., 6552., 6720., 6888., 7056., 7224., 7392.,
#         7560., 7728., 7896., 8064., 8232., 8400.]),
#  <a list of 50 Patch objects>)

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.hist(x['price'], bins=20, color='orange', edgecolor='black')
# sns.countplot(df3['review_scores_rating'], ax=ax, color='green', edgecolor='black')
# ax.set_title('Ratings by Review')
ax.set_xlim(0,500)
ax.set_xlabel('Nightly Rate', labelpad=30, fontsize=30)
# ax.set_xticks(ticks=[85, 90, 95, 100])
# ax.set_xticklabels([0, 20, 40, 60, 80, 100])
# ax.set_xticklabels([0, .2, .4, .6, .8, 1])

ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)

# ax.set_yticklabels(['', '10,000', '20,000', '30,000', '40,000', '50,000', '60,000'])

ax.set_ylabel('Count', labelpad=30, fontsize=30)

plt.tight_layout()

# plt.savefig('plots/walk_score_and_home_price.jpg')

# %%
df3.head()
# Out:
#     id_x  host_id  host_listings_count  host_total_listings_count  \
# 0   7893    21489                    1                          1
# 1   7893    21489                    1                          1
# 2  12899    49682                    1                          1
# 3  12899    49682                    1                          1
# 4  12899    49682                    1                          1
#
#   neighbourhood zipcode   latitude   longitude property_type        room_type  \
# 0      Piedmont   97217  45.575479 -122.666777         House  Entire home/apt
# 1      Piedmont   97217  45.575479 -122.666777         House  Entire home/apt
# 2     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
# 3     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
# 4     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             3        1.0       2.0   2.0  Real Bed
# 1             3        1.0       2.0   2.0  Real Bed
# 2             3        1.0       2.0   2.0  Real Bed
# 3             3        1.0       2.0   2.0  Real Bed
# 4             3        1.0       2.0   2.0  Real Bed
#
#                                            amenities  price  guests_included  \
# 0  {TV,Wifi,Kitchen,"Free parking on premises","I...    175                1
# 1  {TV,Wifi,Kitchen,"Free parking on premises","I...    175                1
# 2  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
# 3  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                  2                 100.0                    10.0
# 1                  2                 100.0                    10.0
# 2                497                  98.0                    10.0
# 3                497                  98.0                    10.0
# 4                497                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#    instant_bookable  reviews_per_month  listing_id      id_y        date  \
# 0                 0               0.02        7893     27282  2010-02-22
# 1                 0               0.02        7893  17461247  2014-08-12
# 2                 0               4.69       12899     24767  2010-01-24
# 3                 0               4.69       12899     29230  2010-03-13
# 4                 0               4.69       12899     29806  2010-03-16
#
#    reviewer_id reviewer_name  \
# 0        52074         Shaun
# 1     13284006       Jessica
# 2        69327        Stuart
# 3        72846          John
# 4        84196          Lois
#
#                                             comments  \
# 0  Couldn't possibly had a better experience with...
# 1  Jesse's place was really wonderful! The apartm...
# 2  Recommended! Very good value for a spacious, a...
# 3  Our ten days visiting in Portland were enormou...
# 4  We had a wonderful time staying in the area of...
#
#                                  reviews_cleaned_str  polarity  subjectivity  \
# 0  couldnt possibl better experi trip would give ...  0.275000      0.650000
# 1  jess place realli wonder apart locat block awa...  0.275463      0.601852
# 2  recommend good valu spaciou airi upper floor a...  0.370000      0.360000
# 3  day visit portland enorm enhanc alison david c...  0.266667      0.579167
# 4  wonder time stay area alberta artsth bed comfi...  0.408929      0.821429
#
#    review_length                                   cleaned_comments  \
# 0            158  couldnt possibly better experience trip would ...
# 1            670  jesses place really wonderful apartment locate...
# 2            112  recommended good value spacious airy upper flo...
# 3            281  days visiting portland enormously enhanced ali...
# 4            317  wonderful time staying area alberta artsthe be...
#
#    num_sentences                                 comment_words_only  \
# 0              3  couldnt possibly had a better experience with ...
# 1             10  jesses place was really wonderful the apartmen...
# 2              3  recommended very good value for a spacious air...
# 3              4  our ten days visiting in portland were enormou...
# 4              4  we had a wonderful time staying in the area of...
#
#                                     individual_words  word_count  \
# 0  ['couldnt', 'possibly', 'had', 'a', 'better', ...          29
# 1  ['jesses', 'place', 'was', 'really', 'wonderfu...         119
# 2  ['recommended', 'very', 'good', 'value', 'for'...          19
# 3  ['our', 'ten', 'days', 'visiting', 'in', 'port...          44
# 4  ['we', 'had', 'a', 'wonderful', 'time', 'stayi...          57
#
#    average_word_length                              most_frequent_words  \
# 0             4.241379                                               []
# 1             4.436975  [('place', 2), ('really', 2), ('apartment', 2)]
# 2             4.736842                                               []
# 3             5.250000                                [('portland', 2)]
# 4             4.350877                                   [('great', 2)]
#
#    cluster_pred     lda_1     lda_2     lda_3     lda_4     lda_5     lda_6  \
# 0             3  0.272123  0.594522  0.016668  0.016668  0.016672  0.016670
# 1             7  0.002779  0.323845  0.002779  0.002778  0.194300  0.111495
# 2             6  0.012503  0.012501  0.012501  0.012501  0.240606  0.474373
# 3             4  0.014288  0.014292  0.014290  0.014286  0.014296  0.014286
# 4             7  0.005557  0.189475  0.005557  0.005556  0.005558  0.005557
#
#       lda_7     lda_8     lda_9    lda_10
# 0  0.016672  0.016669  0.016668  0.016669
# 1  0.002779  0.002778  0.002778  0.353690
# 2  0.012501  0.012501  0.197512  0.012501
# 3  0.014287  0.871401  0.014288  0.014286
# 4  0.092100  0.005558  0.281088  0.403994

# %%
df3.columns
# Out:
# Index(['id_x', 'host_id', 'host_listings_count', 'host_total_listings_count',
#        'neighbourhood', 'zipcode', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'guests_included',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable', 'reviews_per_month',
#        'listing_id', 'id_y', 'date', 'reviewer_id', 'reviewer_name',
#        'comments', 'reviews_cleaned_str', 'polarity', 'subjectivity',
#        'review_length', 'cleaned_comments', 'num_sentences',
#        'comment_words_only', 'individual_words', 'word_count',
#        'average_word_length', 'most_frequent_words', 'cluster_pred', 'lda_1',
#        'lda_2', 'lda_3', 'lda_4', 'lda_5', 'lda_6', 'lda_7', 'lda_8', 'lda_9',
#        'lda_10'],
#       dtype='object')

# %%
sns.heatmap(df3[['lda_1',
       'lda_2', 'lda_3', 'lda_4', 'lda_5', 'lda_6', 'lda_7', 'lda_8', 'lda_9',
       'lda_10']].corr(), cmap='coolwarm')

# %%
sns.set_context('talk')
sns.set(font_scale=2.0)
plt.figure(figsize=(6,6))
fig, ax = plt.subplots(figsize=(16,12))
sns.heatmap(df3[['lda_1',
       'lda_2', 'lda_3', 'lda_4', 'lda_5', 'lda_6', 'lda_7', 'lda_8', 'lda_9',
       'lda_10']].corr(), cmap='coolwarm')
# plt.tight_layout()

# %%
df3.head()
# Out:
#     id_x  host_id  host_listings_count  host_total_listings_count  \
# 0   7893    21489                    1                          1
# 1   7893    21489                    1                          1
# 2  12899    49682                    1                          1
# 3  12899    49682                    1                          1
# 4  12899    49682                    1                          1
#
#   neighbourhood zipcode   latitude   longitude property_type        room_type  \
# 0      Piedmont   97217  45.575479 -122.666777         House  Entire home/apt
# 1      Piedmont   97217  45.575479 -122.666777         House  Entire home/apt
# 2     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
# 3     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
# 4     Concordia   97211  45.564010 -122.634717   Guest suite     Private room
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             3        1.0       2.0   2.0  Real Bed
# 1             3        1.0       2.0   2.0  Real Bed
# 2             3        1.0       2.0   2.0  Real Bed
# 3             3        1.0       2.0   2.0  Real Bed
# 4             3        1.0       2.0   2.0  Real Bed
#
#                                            amenities  price  guests_included  \
# 0  {TV,Wifi,Kitchen,"Free parking on premises","I...    175                1
# 1  {TV,Wifi,Kitchen,"Free parking on premises","I...    175                1
# 2  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
# 3  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
# 4  {Internet,Wifi,"Air conditioning",Kitchen,"Pet...     65                2
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# 0                  2                 100.0                    10.0
# 1                  2                 100.0                    10.0
# 2                497                  98.0                    10.0
# 3                497                  98.0                    10.0
# 4                497                  98.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                    10.0                 10.0
# 1                         10.0                    10.0                 10.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#    instant_bookable  reviews_per_month  listing_id      id_y        date  \
# 0                 0               0.02        7893     27282  2010-02-22
# 1                 0               0.02        7893  17461247  2014-08-12
# 2                 0               4.69       12899     24767  2010-01-24
# 3                 0               4.69       12899     29230  2010-03-13
# 4                 0               4.69       12899     29806  2010-03-16
#
#    reviewer_id reviewer_name  \
# 0        52074         Shaun
# 1     13284006       Jessica
# 2        69327        Stuart
# 3        72846          John
# 4        84196          Lois
#
#                                             comments  \
# 0  Couldn't possibly had a better experience with...
# 1  Jesse's place was really wonderful! The apartm...
# 2  Recommended! Very good value for a spacious, a...
# 3  Our ten days visiting in Portland were enormou...
# 4  We had a wonderful time staying in the area of...
#
#                                  reviews_cleaned_str  polarity  subjectivity  \
# 0  couldnt possibl better experi trip would give ...  0.275000      0.650000
# 1  jess place realli wonder apart locat block awa...  0.275463      0.601852
# 2  recommend good valu spaciou airi upper floor a...  0.370000      0.360000
# 3  day visit portland enorm enhanc alison david c...  0.266667      0.579167
# 4  wonder time stay area alberta artsth bed comfi...  0.408929      0.821429
#
#    review_length                                   cleaned_comments  \
# 0            158  couldnt possibly better experience trip would ...
# 1            670  jesses place really wonderful apartment locate...
# 2            112  recommended good value spacious airy upper flo...
# 3            281  days visiting portland enormously enhanced ali...
# 4            317  wonderful time staying area alberta artsthe be...
#
#    num_sentences                                 comment_words_only  \
# 0              3  couldnt possibly had a better experience with ...
# 1             10  jesses place was really wonderful the apartmen...
# 2              3  recommended very good value for a spacious air...
# 3              4  our ten days visiting in portland were enormou...
# 4              4  we had a wonderful time staying in the area of...
#
#                                     individual_words  word_count  \
# 0  ['couldnt', 'possibly', 'had', 'a', 'better', ...          29
# 1  ['jesses', 'place', 'was', 'really', 'wonderfu...         119
# 2  ['recommended', 'very', 'good', 'value', 'for'...          19
# 3  ['our', 'ten', 'days', 'visiting', 'in', 'port...          44
# 4  ['we', 'had', 'a', 'wonderful', 'time', 'stayi...          57
#
#    average_word_length                              most_frequent_words  \
# 0             4.241379                                               []
# 1             4.436975  [('place', 2), ('really', 2), ('apartment', 2)]
# 2             4.736842                                               []
# 3             5.250000                                [('portland', 2)]
# 4             4.350877                                   [('great', 2)]
#
#    cluster_pred     lda_1     lda_2     lda_3     lda_4     lda_5     lda_6  \
# 0             3  0.272123  0.594522  0.016668  0.016668  0.016672  0.016670
# 1             7  0.002779  0.323845  0.002779  0.002778  0.194300  0.111495
# 2             6  0.012503  0.012501  0.012501  0.012501  0.240606  0.474373
# 3             4  0.014288  0.014292  0.014290  0.014286  0.014296  0.014286
# 4             7  0.005557  0.189475  0.005557  0.005556  0.005558  0.005557
#
#       lda_7     lda_8     lda_9    lda_10
# 0  0.016672  0.016669  0.016668  0.016669
# 1  0.002779  0.002778  0.002778  0.353690
# 2  0.012501  0.012501  0.197512  0.012501
# 3  0.014287  0.871401  0.014288  0.014286
# 4  0.092100  0.005558  0.281088  0.403994

# %%
import pprint

# %%
df3[1000:].groupby('cluster_pred')[['cluster_pred', 'comments']].tail(3).values
# Out:
# array([[7,
#         'Although short, we thoroughly enjoyed our stay. The apartment was clean & members of our party particularly enjoyed how comfortable the beds were. Also great location!'],
#        [4, 'Great place.'],
#        [7,
#         'This house is classic PDX, and was very comfortable and homey for our 3-night stay. Nice design, great kitchen and entertaining amenities (like a blender and phone-ready stereo) Everything was really clean, and Amber was a great host, accommodating our special request which made our trip so much less stressful. The coffeeshop on stark has great pie, coffee and hard cider. We enjoyed a great walk up and down nearby Mt Tabor. Would totally stay here again.'],
#        [2,
#         'I stayed for work and was looking for privacy and not a shared bathroom and found a terrific home. Elie was very hospitable and provided an ironing board to use. His place is popular but I’ll stay again if available.'],
#        [2,
#         'This is a relatively spacious, private entry basement unit including a living room, bed room, bathroom and kitchen area with a sink and microwave (no stove).  Internet service was great, the unit was clean, and mostly quiet.  We could hear some activity from upstairs during the day but that usually ceased before 10 p.m.  The bathroom is quite large and everything in it worked well.   One great feature is that parking in the narrow driveway is allowed.  That helped a lot because the street could get pretty parked up at times.  The location is terrific, one block off of Hawthorne which is full of shops and restaurants, yet the unit itself is on a very lightly trafficked, quiet street.  We took a short walk  each morning for breakfast and had lots of choices from Starbucks to several great local cafés within only a couple of blocks.  There are also bars, boutiques, and even a movie theater close by.  Marc, the host, was very responsive and quick to offer help via messaging.  We never actually saw him.   I would definitely stay here again.'],
#        [5,
#         "Great hospitality. I felt like I was their family. Beautiful artistic house interior. Nice garden with vegetables. Lovely dog. It's not in middle of the city but easy access to the city center (30 minutes) and airport (20 minutes by car). I will definitely come back here next time."],
#        [3,
#         'Miranda has a great, spacious and clean house with several rooms for air bnb. The access is very easy and there are enough parking spots. Miranda and her partner were very friendly, open and helpful. The little amenities like tea and snaks were lovely, also the fresh lemon cucumbers from the garden.  We felt like home, thanks for hosting us!'],
#        [3,
#         'The perfect place to stay when traveling. It was everything we expected from an Airbnb and more. Hospitality, beauty, comfort cleanliness, and so much more. We will always stay here when we visit Portland!'],
#        [1,
#         'Amazing host! Super friendly, generous, and hospitable. Well decorated, clean home. Was flexible with check in, which was much appreciated. Sweet dog!'],
#        [3,
#         'This place was awesome. Both hosts were extremely hospitable and made me feel welcome and comfortable in Portland.'],
#        [0,
#         'Very nice house, we had a lovely stay and the cats are very friendly!'],
#        [4, 'Definitely staying here again in the future.'],
#        [1,
#         'Cindy is such a lovely person and so is her home! Excellent communication, cozy room and comfortable bed, and fantastic location in a beautiful area of Portland. Thank you so much for everything!!'],
#        [4, '最高の空間でした'],
#        [7, 'Good crash pad and coffee at the ready in the am.'],
#        [5,
#         'Beautiful apartment located right on the Columbia across from Jantzen Beach. Very quiet neighborhood with lots of friendly neighbors. Beth was a great hostess!'],
#        [5,
#         "Liz was an amazing host! It's a great 1 bedroom apartment with an extremely cute setup! Tucked away in the forest but still close to downtown, just like the ad says. The porch is really convenient and there's a creek right outside the apartment, as well as lots of beautiful foliage. I Highly recommend this Air bnb!"],
#        [6,
#         'The place was clean and quiet.\nLiz was very nice and accommodating. We were comfortable and had an overall very nice stay'],
#        [0,
#         'This is a great house.  Alas AirBnB seems to have screwed up with a change in rental agent.  Our rental was canceled at midnight on the night before we were to fly across the country.  I woke up in the night and rebooked the same dates, same house.  AirBnB was not helpful and said they were unable to reach the new rental agent.  House was great.  Previous reviews complained about the beds which were great.  Wonderful location just off Alberta.'],
#        [6,
#         "Moda Center. As a new host to air bnb, Doug was very quick with communication and receptive to the few suggestions I had for his place. I'm sure he'll be quick to implement them and his place will be a gem."],
#        [1, 'Feel at home in this cozy apartment with a great view2'],
#        [0,
#         'We had a great experience. The house has all the amenities required. Very clean and everything was as it is listed on her Airbnb page. Would highly recommend. Thank you, rekha.'],
#        [6,
#         'Thank you for hosting and I appreciate the good communication! Highly recommend A++'],
#        [2,
#         "Ellie's place was terrific. Everything is new and very comfortable. The living room, dining room, and kitchen provide a big social space with room to move around. The king bed was very comfortable. The place was very clean and well lit. There is a light that is motion detected when you come in the door in the back yard. \n\nI really liked how the place was decorated, there is a very nice color scheme and the furnishings were very comfortable and cozy. Mt. Tabor park is just a block away and the cute shopping areas of Hawthorn and Division are 5 mins away. I didn't get to try the coffee shop on the corner, but it looked very nice. \n\nI was staying due to a family member in the hospital at OHSU, Ellie's place was 20 mins away and a convenient place to stay. \n\nHope to stay at Ellie's place again!"]],
#       dtype=object)

# %%
df3.shape
# Out:
# (318262, 56)

# %%
df3['listing_id'].nunique()
# Out:
# 4911

# %%
sns.countplot(df3['cluster_pred'], color='orange')

# %%
df3.groupby('cluster_pred')[['polarity', 'subjectivity',
       'review_length', 'cleaned_comments', 'num_sentences',
       'comment_words_only', 'individual_words', 'word_count',
       'average_word_length', 'cluster_pred', 'lda_1',
       'lda_2', 'lda_3', 'lda_4', 'lda_5', 'lda_6', 'lda_7', 'lda_8', 'lda_9',
       'lda_10']].mean()
# Out:
#               polarity  subjectivity  review_length  num_sentences  \
# cluster_pred
# 0             0.440689      0.638884     314.496165       4.647323
# 1             0.473774      0.688483     199.775064       3.522777
# 2             0.337065      0.608635     462.446489       6.071456
# 3             0.424346      0.643549     358.339117       4.989024
# 4             0.385100      0.581711     241.938309       3.760938
# 5             0.357570      0.590690     288.037677       4.236370
# 6             0.535920      0.703157     146.560133       2.964040
# 7             0.421458      0.641912     308.155472       4.547488
#
#               word_count  average_word_length  cluster_pred     lda_1  \
# cluster_pred
# 0              57.151210             4.414957           0.0  0.517161
# 1              34.958535             4.692053           1.0  0.053082
# 2              84.010777             4.400512           2.0  0.062016
# 3              65.137159             4.389457           3.0  0.073568
# 4              43.116212             4.384279           4.0  0.064315
# 5              51.497415             4.534450           5.0  0.057452
# 6              25.614509             4.747692           6.0  0.047665
# 7              54.374869             4.589028           7.0  0.054451
#
#                  lda_2     lda_3     lda_4     lda_5     lda_6     lda_7  \
# cluster_pred
# 0             0.059919  0.051656  0.034378  0.061778  0.063115  0.051448
# 1             0.052185  0.041862  0.039701  0.541087  0.068706  0.047649
# 2             0.056905  0.058641  0.032985  0.065904  0.062886  0.045277
# 3             0.489783  0.051078  0.030815  0.068617  0.059975  0.054635
# 4             0.060347  0.057555  0.091046  0.078386  0.080305  0.330418
# 5             0.054294  0.474306  0.047715  0.064709  0.079418  0.052349
# 6             0.040221  0.046003  0.038263  0.058672  0.580715  0.046920
# 7             0.057304  0.060823  0.044857  0.069047  0.072619  0.052152
#
#                  lda_8     lda_9    lda_10
# cluster_pred
# 0             0.054682  0.059742  0.046121
# 1             0.058185  0.055604  0.041939
# 2             0.038625  0.526229  0.050532
# 3             0.052573  0.069869  0.049088
# 4             0.125043  0.061118  0.051468
# 5             0.051973  0.063502  0.054282
# 6             0.051280  0.049867  0.040394
# 7             0.050538  0.066106  0.472103

# %%
df3.columns
# Out:
# Index(['id_x', 'host_id', 'host_listings_count', 'host_total_listings_count',
#        'neighbourhood', 'zipcode', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'guests_included',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable', 'reviews_per_month',
#        'listing_id', 'id_y', 'date', 'reviewer_id', 'reviewer_name',
#        'comments', 'reviews_cleaned_str', 'polarity', 'subjectivity',
#        'review_length', 'cleaned_comments', 'num_sentences',
#        'comment_words_only', 'individual_words', 'word_count',
#        'average_word_length', 'most_frequent_words', 'cluster_pred', 'lda_1',
#        'lda_2', 'lda_3', 'lda_4', 'lda_5', 'lda_6', 'lda_7', 'lda_8', 'lda_9',
#        'lda_10'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(15,10))

inertia = [138372.08666666667, 138077.9732696004, 135011.2854062694, 134342.35315319823, 138116.5294270795, 132038.03966021142, 132660.12220458066, 133375.44334290357, 132207.39414966636, 132414.58396806827, 134633.49015832442, 131490.53814483777, 132185.67904331698, 132127.37076788655, 131646.04328747938, 132317.58229491062, 131574.30763594864, 129648.81514473732, 131132.92476470844, 131302.95814719322]
list_num_clusters = list(range(1,21))
# for num_clusters in list_num_clusters:
#     km = MiniBatchKMeans(n_clusters=num_clusters)
#     km.fit(new2)
#     inertia.append(km.inertia_)
    
plt.plot(list_num_clusters,inertia, linewidth=4)
plt.scatter(list_num_clusters,inertia)
# plt.xlabel('Number of Clusters')
# plt.ylabel('Inertia');

ax.set_ylabel('Inertia (thousands)', labelpad=30, fontsize=30)
ax.set_xlabel('Number of clusters', labelpad=30, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.tick_params(axis='both', which='minor', labelsize=20)


# fig, ax = plt.subplots(figsize=(10,8))
# plt.hist(df3['review_scores_rating'], range=(85,100), bins=15, color = 'orange', edgecolor='black')
# sns.countplot(df3['review_scores_rating'], ax=ax, color='green', edgecolor='black')
# ax.set_title('Ratings by Review')
ax.set_xlim(0,20)

# ax.set_xticks(ticks=[85, 90, 95, 100])
# ax.set_xticklabels([0, 20, 40, 60, 80, 100])
# ax.set_xticklabels([0, .2, .4, .6, .8, 1])



# ax.set_yticklabels(['', '10,000', '20,000', '30,000', '40,000', '50,000', '60,000'])



plt.tight_layout()

# plt.savefig('plots/walk_score_and_home_price.jpg')
